# %% [markdown]
# ### Install the latest version of bio-compose from PyPI:

# %%
# !pip install --upgrade pip -q && pip install -q --no-cache-dir bio-compose
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 104.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 95.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 273.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Run the SBML verification, specifying the model filepath, start time, stop time, and number of steps:

# %%
import bio_compose

verification = bio_compose.verify('/content/BorisEJB.xml', 0, 1000, 2000)
# Out:
# > Status for job ending in 7d0e: SUBMITTED:PENDING
# > Status for job ending in 7d0e: COMPLETED

# %% [markdown]
# ### Visualize observable outputs:

# %%
observables = verification.get_output_observables()

# %% [markdown]
# ### Visualize root-mean-square error results for each simulator accross all observables

# %%
comparison = verification.get_comparison()
